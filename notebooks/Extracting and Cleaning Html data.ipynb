# %% [markdown]
# # Cleaning HTML and outputting preannotation files

# %%
# %%writefile DebattenDatacleaner.py

import os
import re

class DebattenDatacleaner:
    """
    Takes raw html files and extractes the sentences and their timestamps.
    """
    
    # Initialises class and input, output locations
    def __init__(self, loc_raw=[], loc_pro=[]):
        self.loc_raw_subtitles = loc_raw
        self.loc_pro_subtitles = loc_pro
    
    def setRawFilesLocation(self, new_loc):
        self.loc_raw_subtitles = new_loc
        
    def setProcessedFilesLocation(self, new_loc):
        self.loc_pro_subtitles = new_loc
    
    def getFileLocation(self, disp=True):
        
        if disp:
            if not self.loc_raw_subtitles:
                print('Raw subtitles are not specified!')
            else:
                print('Raw subtitles are loaded from "{:s}"'.format(self.loc_raw_subtitles))

            if not self.loc_pro_subtitles:
                print('Save location for processed subtitles is not specified!')
            else:
                print('Save location for processed subtitles is "{:s}"'.format(self.loc_pro_subtitles))
       
        return self.loc_raw_subtitles, self.loc_pro_subtitles
    
    # Returns the full (or relative) path all the raw files
    def getRawFilePaths(self, filename='page.html', subset=None):
        
        program_ids = os.listdir(self.loc_raw_subtitles)
        files = ['{:s}{:s}/{:s}'.format(self.loc_raw_subtitles, p_id, filename) for p_id in program_ids]
        
        if subset and abs(subset) < len(files):
            if subset < 0:
                files = files[subset:]
                program_ids = program_ids[subset:]
            else:
                files = files[:subset]
                program_ids = program_ids[:subset]
        
        return files, program_ids
    
    
    def html_decode(self, s):
        """
        Returns the ASCII decoded version of the given HTML string. This does
        NOT remove normal HTML tags like <p>.
        """
        htmlCodes = (
                ("'", '&#39;'),
                ('"', '&quot;'),#("'", '&quot;'),#
                ('>', '&gt;'),
                ('<', '&lt;'),
                ('&', '&amp;')
            )
        for code in htmlCodes:
            s = s.replace(code[1], code[0])
        return s

    # Extract the relevant HTML text for each sentence
    def getHtmlSentences(self, file_loc, re_subs_pattern='category="Undertekster"[\S\W<>]+<script src="/',
                                split_pattern='<span class="digits ng-binding">'):
        subtitle_file = open(file_loc,'r', encoding='iso-8859-1')
        #subtitle_file = open(file_loc,'r', encoding='utf-8', errors='ignore')
        doc = subtitle_file.read()
        doc = self.html_decode(doc)

        subtitle_file.close()

        # Find part of the html which contain the subtitles
        p_subs = re.compile(re_subs_pattern)
        match = re.search(p_subs,doc)
        doc_subs = match.group()

        #Split into the sentences
        sentences = doc_subs.split(split_pattern)
        sentences = [sentences[i] for i in range(1,len(sentences))]

        print('\tProgram has {:d} sentences'.format(len(sentences)))
        return sentences
    
    
    def getTimeAndText(self, text, re_time='[\d:]+', re_text='ma-highlight="[\w?%!:-; \',.\d-]+'):
        p_time = re.compile(re_time)
        p_text = re.compile(re_text)
        
        text_at_this_timepoint = re.finditer(p_text,text)
        s = ''
        for match in text_at_this_timepoint:
            s=s+' '+(match.group()[14:])

        s = re.sub(' +',' ',s) # Removes repeating whitespaces
        s=s[1:] # Removes first white space

        nums = re.finditer(p_time,text)
        nums = [n.group() for n in nums]

        time_start = nums[0]
        time_end = nums[1]

        return s, time_start, time_end
    
    def getCleanedSentences(self, sentences):
        program = []
        start_times = []
        end_times = []

        for sen in sentences:
            text, start, end = self.getTimeAndText(sen)

            if len(program) is 0:
                program.append(text)
                start_times.append(start)
                end_times.append(end)
            elif len(text)>0:
                try:

                    if text[0] is '-':
                        last_text = program.pop()
                        s = last_text+text
                        s = re.sub('- ',' ',s)
                        s = re.sub(' -',' ',s)
                        s = re.sub(' +',' ',s)

                        program.append(s)

                        end_times.pop()
                        end_times.append(end)

                    else:
                        program.append(text)
                        start_times.append(start)
                        end_times.append(end)

                except Exception as e:
                    print('Woops.. ')
                    print('"',text,'"')
                    print(len(text))

        print('\tProgram has {:d} cleaned sentences'.format(len(program)))
        return dict(zip(['sentences','start time','end time'],[program, start_times, end_times]))


    def getCleanedPrograms(self, file_paths, program_ids):
        total_sent = 0
        all_programs = dict()
        count = 1;
        for i in range(len(file_paths)):
            print('Program {:d} of {:d} ({:s})'.format(i+1,len(file_paths),program_ids[i]))
            program_sentences = self.getHtmlSentences(file_paths[i])
            all_programs[program_ids[i]] = self.getCleanedSentences(program_sentences)
            total_sent += len(all_programs[program_ids[i]]['sentences'])
            
        print('\nA total of {:d} sentences was found.'.format(total_sent))
            
        return all_programs
    
    def export_debatten_programs(self, all_programs, program_ids ):
                                 
        for p_id in all_programs:
            sentenc_id = 1
            with open(self.loc_pro_subtitles+'program'+str(p_id), 'w') as f:
                f.write('<span id="program '+str(p_id)+'">\n')

                for s in all_programs[p_id]['sentences']:
                    f.write('\t<p id="'+str(p_id)+'"> '+s+' </p>\n')
                    sentenc_id+=1

                f.write('</span>')
            print('Sucessfully wrote program'+str(p_id))
    
    
#for i in range(len(all_programs)):
    #export_debatten_program(all_programs['program-'+directories[i]],directories[i])
# Out:
# Overwriting DebattenDatacleaner.py

# %%
from DebattenDatacleaner import DebattenDatacleaner

Datacleaner = DebattenDatacleaner('/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/',
                                  '../Results/DeepFact/2017-10-17-Instance/')
Datacleaner.getFileLocation();
# Out:
# Raw subtitles are loaded from "/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/"
# Save location for processed subtitles is "../Results/DeepFact/2017-10-17-Instance/"

# %%
files, program_id = Datacleaner.getRawFilePaths()

print('The ten first examples are')
Datacleaner.getRawFilePaths(subset=10)
# Out:
# The ten first examples are
# (['/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/6047910/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/5779637/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/7162934/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/7115504/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/4027193/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/6066238/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/8610238/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/2512262/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/5984995/page.html',
#   '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/6556275/page.html'],
#  ['6047910',
#   '5779637',
#   '7162934',
#   '7115504',
#   '4027193',
#   '6066238',
#   '8610238',
#   '2512262',
#   '5984995',
#   '6556275'])

# %%
# For debugging
files[0] = '/home/jehi/Dropbox/DTU/DeepFactData/Subtitles Crawl/9024801/page.html'
program_id[0] = '9024801'

# %%
program_sentences = Datacleaner.getHtmlSentences(files[0])
# Out:
# 	Program has 3424 sentences

# %%
Datacleaner.getTimeAndText(program_sentences[0])
# Out:
# ('Politikerne tog fejl, både demokrater og republikanere.',
#  '21:00:25:23',
#  '21:00:26:18')

# %%
cleaned_sentences = Datacleaner.getCleanedSentences(program_sentences)
# Out:
# 	Program has 3314 cleaned sentences

# %%
all_programs = Datacleaner.getCleanedPrograms(files, program_id)
# Out:
# Program 1 of 198 (9024801)
# 	Program has 3424 sentences
# 	Program has 3314 cleaned sentences
# Program 2 of 198 (5779637)
# 	Program has 473 sentences
# 	Program has 360 cleaned sentences
# Program 3 of 198 (7162934)
# 	Program has 736 sentences
# 	Program has 529 cleaned sentences
# Program 4 of 198 (7115504)
# 	Program has 742 sentences
# 	Program has 538 cleaned sentences
# Program 5 of 198 (4027193)
# 	Program has 510 sentences
# 	Program has 391 cleaned sentences
# Program 6 of 198 (6066238)
# 	Program has 630 sentences
# 	Program has 457 cleaned sentences
# Program 7 of 198 (8610238)
# 	Program has 792 sentences
# 	Program has 526 cleaned sentences
# Program 8 of 198 (2512262)
# 	Program has 461 sentences
# 	Program has 338 cleaned sentences
# Program 9 of 198 (5984995)
# 	Program has 577 sentences
# 	Program has 426 cleaned sentences
# Program 10 of 198 (6556275)
# 	Program has 609 sentences
# 	Program has 429 cleaned sentences
# Program 11 of 198 (1808661)
# 	Program has 429 sentences
# 	Program has 321 cleaned sentences
# Program 12 of 198 (1777290)
# 	Program has 534 sentences
# 	Program has 441 cleaned sentences
# Program 13 of 198 (4103318)
# 	Program has 484 sentences
# 	Program has 371 cleaned sentences
# Program 14 of 198 (2765236)
# 	Program has 440 sentences
# 	Program has 314 cleaned sentences
# Program 15 of 198 (6097134)
# 	Program has 618 sentences
# 	Program has 469 cleaned sentences
# Program 16 of 198 (8573626)
# 	Program has 1 sentences
# 	Program has 1 cleaned sentences
# Program 17 of 198 (3588676)
# 	Program has 413 sentences
# 	Program has 271 cleaned sentences
# Program 18 of 198 (4042060)
# 	Program has 481 sentences
# 	Program has 366 cleaned sentences
# Program 19 of 198 (2455625)
# 	Program has 418 sentences
# 	Program has 311 cleaned sentences
# Program 20 of 198 (5126491)
# 	Program has 575 sentences
# 	Program has 402 cleaned sentences
# Program 21 of 198 (2232356)
# 	Program has 445 sentences
# 	Program has 410 cleaned sentences
# Program 22 of 198 (2294023)
# 	Program has 420 sentences
# 	Program has 320 cleaned sentences
# Program 23 of 198 (2304494)
# 	Program has 477 sentences
# 	Program has 334 cleaned sentences
# Program 24 of 198 (5578714)
# 	Program has 600 sentences
# 	Program has 439 cleaned sentences
# Program 25 of 198 (6000178)
# 	Program has 618 sentences
# 	Program has 429 cleaned sentences
# Program 26 of 198 (4784978)
# 	Program has 594 sentences
# 	Program has 422 cleaned sentences
# Program 27 of 198 (2573324)
# 	Program has 709 sentences
# 	Program has 519 cleaned sentences
# Program 28 of 198 (1748819)
# 	Program has 453 sentences
# 	Program has 332 cleaned sentences
# Program 29 of 198 (2092024)
# 	Program has 441 sentences
# 	Program has 312 cleaned sentences
# Program 30 of 198 (2250789)
# 	Program has 493 sentences
# 	Program has 352 cleaned sentences
# Program 31 of 198 (1369970)
# 	Program has 426 sentences
# 	Program has 303 cleaned sentences
# Program 32 of 198 (2466477)
# 	Program has 459 sentences
# 	Program has 346 cleaned sentences
# Program 33 of 198 (6113249)
# 	Program has 630 sentences
# 	Program has 467 cleaned sentences
# Program 34 of 198 (5186364)
# 	Program has 588 sentences
# 	Program has 421 cleaned sentences
# Program 35 of 198 (6129385)
# 	Program has 625 sentences
# 	Program has 439 cleaned sentences
# Program 36 of 198 (5624194)
# 	Program has 586 sentences
# 	Program has 422 cleaned sentences
# Program 37 of 198 (2593416)
# 	Program has 444 sentences
# 	Program has 314 cleaned sentences
# Program 38 of 198 (8568906)
# 	Program has 697 sentences
# 	Program has 518 cleaned sentences
# Program 39 of 198 (4914022)
# 	Program has 595 sentences
# 	Program has 437 cleaned sentences
# Program 40 of 198 (3693287)
# 	Program has 358 sentences
# 	Program has 251 cleaned sentences
# Program 41 of 198 (5762858)
# 	Program has 591 sentences
# 	Program has 428 cleaned sentences
# Program 42 of 198 (6628084)
# 	Program has 599 sentences
# 	Program has 426 cleaned sentences
# Program 43 of 198 (3411204)
# 	Program has 566 sentences
# 	Program has 406 cleaned sentences
# Program 44 of 198 (6599121)
# 	Program has 606 sentences
# 	Program has 458 cleaned sentences
# Program 45 of 198 (8571627)
# 	Program has 8 sentences
# 	Program has 8 cleaned sentences
# Program 46 of 198 (7077142)
# 	Program has 727 sentences
# 	Program has 514 cleaned sentences
# Program 47 of 198 (5216837)
# 	Program has 611 sentences
# 	Program has 433 cleaned sentences
# Program 48 of 198 (3505973)
# 	Program has 426 sentences
# 	Program has 300 cleaned sentences
# Program 49 of 198 (4682044)
# 	Program has 357 sentences
# 	Program has 257 cleaned sentences
# Program 50 of 198 (8568658)
# 	Program has 791 sentences
# 	Program has 523 cleaned sentences
# Program 51 of 198 (4155377)
# 	Program has 683 sentences
# 	Program has 506 cleaned sentences
# Program 52 of 198 (3550014)
# 	Program has 430 sentences
# 	Program has 317 cleaned sentences
# Program 53 of 198 (3467995)
# 	Program has 409 sentences
# 	Program has 284 cleaned sentences
# Program 54 of 198 (5287397)
# 	Program has 619 sentences
# 	Program has 419 cleaned sentences
# Program 55 of 198 (4753167)
# 	Program has 593 sentences
# 	Program has 433 cleaned sentences
# Program 56 of 198 (8524981)
# 	Program has 765 sentences
# 	Program has 593 cleaned sentences
# Program 57 of 198 (2370770)
# 	Program has 451 sentences
# 	Program has 310 cleaned sentences
# Program 58 of 198 (2011161)
# 	Program has 483 sentences
# 	Program has 355 cleaned sentences
# Program 59 of 198 (6514284)
# 	Program has 562 sentences
# 	Program has 411 cleaned sentences
# Program 60 of 198 (5252755)
# 	Program has 467 sentences
# 	Program has 324 cleaned sentences
# Program 95 of 198 (6183773)
# 	Program has 631 sentences
# 	Program has 469 cleaned sentences
# Program 96 of 198 (3632763)
# 	Program has 372 sentences
# 	Program has 240 cleaned sentences
# Program 97 of 198 (3648942)
# 	Program has 355 sentences
# 	Program has 227 cleaned sentences
# Program 98 of 198 (4717985)
# 	Program has 599 sentences
# 	Program has 442 cleaned sentences
# Program 99 of 198 (4845589)
# 	Program has 591 sentences
# 	Program has 409 cleaned sentences
# Program 100 of 198 (4624779)
# 	Program has 607 sentences
# 	Program has 441 cleaned sentences
# Program 101 of 198 (3445438)
# 	Program has 396 sentences
# 	Program has 288 cleaned sentences
# Program 102 of 198 (5559662)
# 	Program has 721 sentences
# 	Program has 497 cleaned sentences
# Program 103 of 198 (6168649)
# 	Program has 606 sentences
# 	Program has 444 cleaned sentences
# Program 104 of 198 (2443022)
# 	Program has 418 sentences
# 	Program has 299 cleaned sentences
# Program 105 of 198 (8793533)
# 	Program has 6482 sentences
# 	Program has 6387 cleaned sentences
# Program 106 of 198 (1817762)
# 	Program has 445 sentences
# 	Program has 327 cleaned sentences
# Program 107 of 198 (8364372)
# 	Program has 782 sentences
# 	Program has 561 cleaned sentences
# Program 108 of 198 (8905036)
# 	Program has 6234 sentences
# 	Program has 6065 cleaned sentences
# Program 109 of 198 (2983825)
# 	Program has 431 sentences
# 	Program has 308 cleaned sentences
# Program 110 of 198 (5675832)
# 	Program has 605 sentences
# 	Program has 469 cleaned sentences
# Program 111 of 198 (8564875)
# 	Program has 493 sentences
# 	Program has 369 cleaned sentences
# Program 112 of 198 (7103349)
# 	Program has 744 sentences
# 	Program has 507 cleaned sentences
# Program 113 of 198 (4071354)
# 	Program has 488 sentences
# 	Program has 359 cleaned sentences
# Program 114 of 198 (6153407)
# 	Program has 661 sentences
# 	Program has 467 cleaned sentences
# Program 115 of 198 (2500720)
# 	Program has 457 sentences
# 	Program has 314 cleaned sentences
# Program 116 of 198 (5964390)
# 	Program has 607 sentences
# 	Program has 396 cleaned sentences
# Program 117 of 198 (5085179)
# 	Program has 582 sentences
# 	Program has 402 cleaned sentences
# Program 118 of 198 (2315222)
# 	Program has 599 sentences
# 	Program has 443 cleaned sentences
# Program 119 of 198 (8665813)
# 	Program has 781 sentences
# 	Program has 561 cleaned sentences
# Program 120 of 198 (5639601)
# 	Program has 572 sentences
# 	Program has 398 cleaned sentences
# Program 121 of 198 (5742743)
# 	Program has 587 sentences
# 	Program has 429 cleaned sentences
# Program 122 of 198 (1767521)
# 	Program has 411 sentences
# 	Program has 295 cleaned sentences
# Program 123 of 198 (5655525)
# 	Program has 629 sentences
# 	Program has 479 cleaned sentences
# Program 124 of 198 (4541683)
# 	Program has 583 sentences
# 	Program has 441 cleaned sentences
# Program 125 of 198 (1828042)
# 	Program has 393 sentences
# 	Program has 266 cleaned sentences
# Program 126 of 198 (2337314)
# 	Program has 485 sentences
# 	Program has 318 cleaned sentences
# Program 127 of 198 (8689224)
# 	Program has 780 sentences
# 	Program has 541 cleaned sentences
# Program 128 of 198 (2716313)
# 	Program has 456 sentences
# 	Program has 319 cleaned sentences
# Program 129 of 198 (4515168)
# 	Program has 614 sentences
# 	Program has 443 cleaned sentences
# Program 130 of 198 (2282900)
# 	Program has 436 sentences
# 	Program has 306 cleaned sentences
# Program 131 of 198 (5200088)
# 	Program has 609 sentences
# 	Program has 456 cleaned sentences
# Program 132 of 198 (1962590)
# 	Program has 465 sentences
# 	Program has 313 cleaned sentences
# Program 133 of 198 (6584872)
# 	Program has 603 sentences
# 	Program has 450 cleaned sentences
# Program 134 of 198 (2222122)
# 	Program has 485 sentences
# 	Program has 374 cleaned sentences
# Program 135 of 198 (7186318)
# 	Program has 732 sentences
# 	Program has 536 cleaned sentences
# Program 136 of 198 (5236713)
# 	Program has 598 sentences
# 	Program has 374 cleaned sentences
# Program 137 of 198 (6443809)
# 	Program has 542 sentences
# 	Program has 398 cleaned sentences
# Program 138 of 198 (7127382)
# 	Program has 740 sentences
# 	Program has 531 cleaned sentences
# Program 139 of 198 (7139464)
# 	Program has 741 sentences
# 	Program has 511 cleaned sentences
# Program 140 of 198 (5158985)
# 	Program has 610 sentences
# 	Program has 403 cleaned sentences
# Program 141 of 198 (4266979)
# 	Program has 674 sentences
# 	Program has 496 cleaned sentences
# Program 142 of 198 (3427186)
# 	Program has 574 sentences
# 	Program has 428 cleaned sentences
# Program 143 of 198 (6570340)
# 	Program has 615 sentences
# 	Program has 450 cleaned sentences
# Program 144 of 198 (2624937)
# 	Program has 443 sentences
# 	Program has 341 cleaned sentences
# Program 145 of 198 (1037984)
# 	Program has 425 sentences
# 	Program has 305 cleaned sentences
# Program 146 of 198 (6528165)
# 	Program has 542 sentences
# 	Program has 402 cleaned sentences
# Program 147 of 198 (2040383)
# 	Program has 369 sentences
# 	Program has 255 cleaned sentences
# Program 148 of 198 (6542606)
# 	Program has 561 sentences
# 	Program has 436 cleaned sentences
# Program 149 of 198 (5935745)
# 	Program has 617 sentences
# 	Program has 443 cleaned sentences
# Program 150 of 198 (8635201)
# 	Program has 790 sentences
# 	Program has 526 cleaned sentences
# Program 151 of 198 (5171937)
# 	Program has 585 sentences
# 	Program has 451 cleaned sentences
# Program 152 of 198 (2020168)
# 	Program has 459 sentences
# 	Program has 322 cleaned sentences
# Program 153 of 198 (8567636)
# 	Program has 457 sentences
# 	Program has 340 cleaned sentences
# Program 154 of 198 (7198080)
# 	Program has 733 sentences
# 	Program has 495 cleaned sentences
# Program 155 of 198 (3570949)
# 	Program has 427 sentences
# 	Program has 307 cleaned sentences
# Program 156 of 198 (8975996)
# 	Program has 4459 sentences
# 	Program has 4422 cleaned sentences
# Program 157 of 198 (3526461)
# 	Program has 421 sentences
# 	Program has 258 cleaned sentences
# Program 158 of 198 (4828102)
# 	Program has 604 sentences
# 	Program has 442 cleaned sentences
# Program 159 of 198 (8490432)
# 	Program has 810 sentences
# 	Program has 559 cleaned sentences
# Program 160 of 198 (1425182)
# 	Program has 472 sentences
# 	Program has 314 cleaned sentences
# Program 161 of 198 (7146484)
# 	Program has 751 sentences
# 	Program has 545 cleaned sentences
# Program 162 of 198 (3608907)
# 	Program has 365 sentences
# 	Program has 239 cleaned sentences
# Program 163 of 198 (1942591)
# 	Program has 443 sentences
# 	Program has 294 cleaned sentences
# Program 164 of 198 (4056784)
# 	Program has 490 sentences
# 	Program has 368 cleaned sentences
# Program 165 of 198 (1739323)
# 	Program has 431 sentences
# 	Program has 305 cleaned sentences
# Program 166 of 198 (7174872)
# 	Program has 742 sentences
# 	Program has 523 cleaned sentences
# Program 167 of 198 (6642870)
# 	Program has 597 sentences
# 	Program has 437 cleaned sentences
# Program 168 of 198 (5300885)
# 	Program has 607 sentences
# 	Program has 423 cleaned sentences
# Program 169 of 198 (2523604)
# 	Program has 581 sentences
# 	Program has 441 cleaned sentences
# Program 170 of 198 (7090401)
# 	Program has 738 sentences
# 	Program has 539 cleaned sentences
# Program 171 of 198 (9024801)
# 	Program has 3424 sentences
# 	Program has 3314 cleaned sentences
# Program 172 of 198 (2359717)
# 	Program has 441 sentences
# 	Program has 309 cleaned sentences
# Program 173 of 198 (3488287)
# 	Program has 406 sentences
# 	Program has 281 cleaned sentences
# Program 174 of 198 (1932144)
# 	Program has 611 sentences
# 	Program has 443 cleaned sentences
# Program 175 of 198 (3720490)
# 	Program has 420 sentences
# 	Program has 293 cleaned sentences
# Program 176 of 198 (3662558)
# 	Program has 345 sentences
# 	Program has 231 cleaned sentences
# Program 177 of 198 (5728721)
# 	Program has 586 sentences
# 	Program has 432 cleaned sentences
# Program 178 of 198 (4121766)
# 	Program has 657 sentences
# 	Program has 493 cleaned sentences
# Program 179 of 198 (4810657)
# 	Program has 595 sentences
# 	Program has 385 cleaned sentences
# Program 180 of 198 (1374585)
# 	Program has 435 sentences
# 	Program has 312 cleaned sentences
# Program 181 of 198 (2061692)
# 	Program has 398 sentences
# 	Program has 281 cleaned sentences
# Program 182 of 198 (8562295)
# 	Program has 399 sentences
# 	Program has 259 cleaned sentences
# Program 183 of 198 (9284846)
# 	Program has 799 sentences
# 	Program has 577 cleaned sentences
# Program 184 of 198 (4223161)
# 	Program has 672 sentences
# 	Program has 496 cleaned sentences
# Program 185 of 198 (5834387)
# 	Program has 471 sentences
# 	Program has 376 cleaned sentences
# Program 186 of 198 (1952770)
# 	Program has 449 sentences
# 	Program has 321 cleaned sentences
# Program 187 of 198 (8376653)
# 	Program has 781 sentences
# 	Program has 554 cleaned sentences
# Program 188 of 198 (6909844)
# 	Program has 739 sentences
# 	Program has 510 cleaned sentences
# Program 189 of 198 (5803916)
# 	Program has 466 sentences
# 	Program has 326 cleaned sentences
# Program 190 of 198 (1012335)
# 	Program has 411 sentences
# 	Program has 300 cleaned sentences
# Program 191 of 198 (6018439)
# 	Program has 625 sentences
# 	Program has 481 cleaned sentences
# Program 192 of 198 (1787519)
# 	Program has 421 sentences
# 	Program has 303 cleaned sentences
# Program 193 of 198 (4574778)
# 	Program has 604 sentences
# 	Program has 459 cleaned sentences
# Program 194 of 198 (6032988)
# 	Program has 619 sentences
# 	Program has 433 cleaned sentences
# Program 195 of 198 (2348260)
# 	Program has 448 sentences
# 	Program has 307 cleaned sentences
# Program 196 of 198 (4207467)
# 	Program has 696 sentences
#  (516, '7308025'),
#  (281, '2061692'),
#  (303, '1369970'),
#  (369, '8564875'),
#  (284, '3467995'),
#  (231, '3662558'),
#  (240, '3632763'),
#  (518, '8568906'),
#  (257, '4682044'),
#  (418, '1797683'),
#  (266, '1828042'),
#  (544, '4171702'),
#  (362, '6500671'),
#  (325, '2669333'),
#  (251, '3693287'),
#  (324, '2488632'),
#  (303, '1787519'),
#  (429, '6556275'),
#  (436, '4879003'),
#  (496, '4266979'),
#  (443, '1932144'),
#  (456, '5200088'),
#  (419, '5287397'),
#  (324, '1335758'),
#  (577, '9284846'),
#  (441, '4541683'),
#  (549, '8415978'),
#  (259, '8562295'),
#  (444, '6168649'),
#  (458, '6599121'),
#  (428, '3427186'),
#  (523, '8568658'),
#  (307, '2535266'),
#  (258, '3526461'),
#  (314, '2593416'),
#  (368, '4056784'),
#  (423, '5300885'),
#  (360, '5779637'),
#  (338, '2512262'),
#  (442, '4828102'),
#  (346, '2466477'),
#  (375, '4087367'),
#  (467, '6153407'),
#  (332, '1748819'),
#  (437, '4914022'),
#  (402, '5085179'),
#  (536, '7186318'),
#  (293, '3720490'),
#  (310, '2370770'),
#  (538, '7115504'),
#  (374, '5236713'),
#  (541, '8689224'),
#  (314, '1425182'),
#  (450, '6584872'),
#  (301, '2000008'),
#  (4422, '8975996'),
#  (371, '4103318'),
#  (439, '5578714'),
#  (402, '6528165'),
#  (429, '5742743'),
#  (411, '6514284'),
#  (309, '2359717'),
#  (433, '6032988'),
#  (447, '6081732'),
#  (394, '2261432'),
#  (506, '4155377'),
#  (457, '6066238'),
#  (529, '7162934'),
#  (395, '5252755'),
#  (450, '6570340'),
#  (341, '2624937'),
#  (433, '5216837'),
#  (409, '4845589'),
#  (6387, '8793533'),
#  (497, '5559662'),
#  (8, '8571627'),
#  (443, '5935745'),
#  (376, '5834387'),
#  (496, '4223161'),
#  (429, '6000178')]

# %% [markdown]
# # Output til Philip

# %%
# !ls ../Results/DeepFact/2017-10-17-Instance/
# Out:
# program1012335	program2315222	program4027193	program5559662	program6642870
# program1037984	program2325751	program4042060	program5578714	program6909844
# program1292098	program2337314	program4056784	program5624194	program7077142
# program1335758	program2348260	program4071354	program5639601	program7090401
# program1347559	program2359717	program4087367	program5655525	program7103349
# program1369970	program2370770	program4103318	program5675832	program7115504
# program1374585	program2443022	program4121766	program5694754	program7127382
# program1425144	program2455625	program4155377	program5714306	program7139464
# program1425182	program2466477	program4171702	program5728721	program7146484
# program1739323	program2488632	program4207467	program5742743	program7162934
# program1748819	program2500720	program4223161	program5762858	program7174872
# program1758460	program2512262	program4254890	program5779637	program7186318
# program1767521	program2523604	program4266979	program5803916	program7198080
# program1777290	program2535266	program4515168	program5834387	program7308025
# program1787519	program2547764	program4541683	program5935745	program8364372
# program1797683	program2560372	program4574778	program5964390	program8376653
# program1808661	program2573324	program4624779	program5984995	program8415978
# program1817762	program2593416	program4682044	program6000178	program8490432
# program1828042	program2624937	program4717985	program6018439	program8524981
# program1837743	program2669333	program4753167	program6032988	program8562295
# program1932144	program2716313	program4784978	program6066238	program8564875
# program1942591	program2765236	program4810657	program6081732	program8567181
# program1952770	program2983825	program4828102	program6097134	program8567636
# program1962590	program3411204	program4845589	program6113249	program8568658
# program1978162	program3427186	program4859285	program6129385	program8568906
# program1989107	program3445438	program4879003	program6153407	program8571627
# program2000008	program3467995	program4914022	program6168649	program8573626
# program2011161	program3488287	program4960526	program6183773	program8610238
# program2020168	program3505973	program5085179	program6443809	program8635201
# program2040383	program3526461	program5126491	program6458522	program8665813
# program2061692	program3550014	program5158985	program6486894	program8689224
# program2092024	program3570949	program5171937	program6500671	program8720741
# program2222122	program3588676	program5186364	program6514284	program8793533
# program2232356	program3608907	program5200088	program6528165	program8905036
# program2250789	program3632763	program5216837	program6542606	program8975996
# program2261432	program3648942	program5236713	program6556275	program9024801
# program2271997	program3662558	program5252755	program6570340	program9284846
# program2282900	program3693287	program5270879	program6584872
# program2294023	program3720490	program5287397	program6599121
# program2304494	program4003816	program5300885	program6628084

# %%
Datacleaner.export_debatten_programs(all_programs, program_id)
# Out:
# Sucessfully wrote program2271997
# Sucessfully wrote program3570949
# Sucessfully wrote program1767521
# Sucessfully wrote program7198080
# Sucessfully wrote program7103349
# Sucessfully wrote program4071354
# Sucessfully wrote program9024801
# Sucessfully wrote program5984995
# Sucessfully wrote program8490432
# Sucessfully wrote program8567181
# Sucessfully wrote program2304494
# Sucessfully wrote program5803916
# Sucessfully wrote program2250789
# Sucessfully wrote program4121766
# Sucessfully wrote program1739323
# Sucessfully wrote program3411204
# Sucessfully wrote program2547764
# Sucessfully wrote program1808661
# Sucessfully wrote program5270879
# Sucessfully wrote program2282900
# Sucessfully wrote program4027193
# Sucessfully wrote program5694754
# Sucessfully wrote program6443809
# Sucessfully wrote program4254890
# Sucessfully wrote program5762858
# Sucessfully wrote program8720741
# Sucessfully wrote program7174872
# Sucessfully wrote program4859285
# Sucessfully wrote program4207467
# Sucessfully wrote program7077142
# Sucessfully wrote program1817762
# Sucessfully wrote program4810657
# Sucessfully wrote program5964390
# Sucessfully wrote program5675832
# Sucessfully wrote program8573626
# Sucessfully wrote program1942591
# Sucessfully wrote program6628084
# Sucessfully wrote program6542606
# Sucessfully wrote program4042060
# Sucessfully wrote program6909844
# Sucessfully wrote program2455625
# Sucessfully wrote program8665813
# Sucessfully wrote program5728721
# Sucessfully wrote program5158985
# Sucessfully wrote program8524981
# Sucessfully wrote program4753167
# Sucessfully wrote program1292098
# Sucessfully wrote program2222122
# Sucessfully wrote program1012335
# Sucessfully wrote program6458522
# Sucessfully wrote program1962590
# Sucessfully wrote program2716313
# Sucessfully wrote program6486894
# Sucessfully wrote program1758460
# Sucessfully wrote program3648942
# Sucessfully wrote program4003816
# Sucessfully wrote program7090401
# Sucessfully wrote program6183773
# Sucessfully wrote program3488287
# Sucessfully wrote program2232356
# Sucessfully wrote program6097134
# Sucessfully wrote program3505973
# Sucessfully wrote program2337314
# Sucessfully wrote program1425144
# Sucessfully wrote program2011161
# Sucessfully wrote program2092024
# Sucessfully wrote program8635201
# Sucessfully wrote program2020168
# Sucessfully wrote program1374585
# Sucessfully wrote program2523604
# Sucessfully wrote program1978162
# Sucessfully wrote program5742743
# Sucessfully wrote program6514284
# Sucessfully wrote program2359717
# Sucessfully wrote program6032988
# Sucessfully wrote program6081732
# Sucessfully wrote program2261432
# Sucessfully wrote program4155377
# Sucessfully wrote program6066238
# Sucessfully wrote program7162934
# Sucessfully wrote program5252755
# Sucessfully wrote program6570340
# Sucessfully wrote program2624937
# Sucessfully wrote program5216837
# Sucessfully wrote program4845589
# Sucessfully wrote program8793533
# Sucessfully wrote program5559662
# Sucessfully wrote program8571627
# Sucessfully wrote program5935745
# Sucessfully wrote program5834387
# Sucessfully wrote program4223161
# Sucessfully wrote program6000178

# %%
# !ls -l -h ../Results/DeepFact/2017-10-17-Instance/
# Out:
# total 9.3M
# -rw-r--r-- 1 jehi unixusers  30K Oct 17 15:18 program1012335
# -rw-r--r-- 1 jehi unixusers  30K Oct 17 15:18 program1037984
# -rw-r--r-- 1 jehi unixusers  31K Oct 17 15:18 program1292098
# -rw-r--r-- 1 jehi unixusers  31K Oct 17 15:18 program1335758
# -rw-r--r-- 1 jehi unixusers  31K Oct 17 15:18 program1347559
# -rw-r--r-- 1 jehi unixusers  30K Oct 17 15:18 program1369970
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1374585
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1425144
# -rw-r--r-- 1 jehi unixusers  33K Oct 17 15:18 program1425182
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1739323
# -rw-r--r-- 1 jehi unixusers  33K Oct 17 15:18 program1748819
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1758460
# -rw-r--r-- 1 jehi unixusers  31K Oct 17 15:18 program1767521
# -rw-r--r-- 1 jehi unixusers  40K Oct 17 15:18 program1777290
# -rw-r--r-- 1 jehi unixusers  31K Oct 17 15:18 program1787519
# -rw-r--r-- 1 jehi unixusers  31K Oct 17 15:18 program1797683
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1808661
# -rw-r--r-- 1 jehi unixusers  33K Oct 17 15:18 program1817762
# -rw-r--r-- 1 jehi unixusers  28K Oct 17 15:18 program1828042
# -rw-r--r-- 1 jehi unixusers  30K Oct 17 15:18 program1837743
# -rw-r--r-- 1 jehi unixusers  44K Oct 17 15:18 program1932144
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1942591
# -rw-r--r-- 1 jehi unixusers  33K Oct 17 15:18 program1952770
# -rw-r--r-- 1 jehi unixusers  33K Oct 17 15:18 program1962590
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1978162
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program1989107
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program2000008
# -rw-r--r-- 1 jehi unixusers  36K Oct 17 15:18 program2011161
# -rw-r--r-- 1 jehi unixusers  33K Oct 17 15:18 program2020168
# -rw-r--r-- 1 jehi unixusers  27K Oct 17 15:18 program2040383
# -rw-r--r-- 1 jehi unixusers  28K Oct 17 15:18 program2061692
# -rw-r--r-- 1 jehi unixusers  32K Oct 17 15:18 program2092024
